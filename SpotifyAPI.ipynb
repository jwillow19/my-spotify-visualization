# %%
import base64
import requests
# urlencode - wrap this around a data dictionary to create a URL ready string 
from urllib.parse import urlencode

import datetime
from secrets import client_id, client_secret

# %%
def convert_ms(millis):
    '''
    convert milliseconds into seconds
    '''
    millis = int(millis)
    seconds=(millis/1000)%60
    seconds = int(seconds)
    minutes=(millis/(1000*60))%60
    minutes = int(minutes)
#     hours=(millis/(1000*60*60))%24
    min2sec = minutes * 60 
    
    return min2sec + seconds
    
#     return ("%d:%d:%d" % (hours, minutes, seconds))

def parse_track(item):
    '''
    Parses one item from the playlist - return artist dictionary
    '''
    track = item['track']
    
    track_name = item['track']['name']
    track_artists = [artist['name'] for artist in track['artists']]
    lead, feature = track_artists[0], track_artists[1:] 
    
    
    album_name, album_image = track['album']['name'], track['album']['images'][0]['url']
    release_date = track['album']['release_date']
    album_popularity = track['popularity']
    duration = convert_ms(track['duration_ms'])
    
    return dict(lead = {'track': track_name,
                                'album': album_name, 
                                'albumImage': album_image,
                                'release_date': release_date,
                                'popularity': album_popularity, 
                                'duration': duration})

# %%
class SpotifyAPI():
    # Placeholder for attributes    
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret= None
    token_endpoint = 'https://accounts.spotify.com/api/token'
    user_id = '12185809439'
    playlist_endpoint = f'https://api.spotify.com/v1/users/{user_id}/playlists'
    
    
    def __init__(self, api_key, client_id=None, client_secret=None, *args, **kwargs):
        # super init - allows it to call any class that its inheriting from        
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
        self.api_key = api_key
    
    def get_client_credentials(self):
        '''
        Returns a base64 encoded string
        '''
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception("Must set client_id and client_secret")
        client_cred = f"{client_id}:{client_secret}"
        client_cred_b64 = base64.b64encode(client_cred.encode())
        return client_cred_b64.decode()
    
    def get_token_headers(self):
        client_cred_b64 = self.get_client_credentials()
        return {
        "Authorization": f"Basic {client_cred_b64}"
    }
    
    def get_bearer_headers(self):
        api_key = self.api_key
        return {
        "Authorization": f"Bearer {api_key}"
    }
    
    
    def get_token_data(self):
        return {
        "grant_type": "client_credentials"
    }
    
    def auth(self):
        token_endpoint = self.token_endpoint
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        
        r = requests.post(token_endpoint, data=token_data, headers=token_headers)

        if r.status_code not in range(200, 299):
            return False
        
        print(f"Status Code: {r.status_code}")
        now = datetime.datetime.now()
        token_response = r.json()
        access_token = token_response['access_token']
        expires_in = token_response['expires_in'] # in seconds
        expires = now + datetime.timedelta(seconds=expires_in) # use datetime to calculate the time of expiration
        
        self.access_token = access_token 
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        self.token_res = token_response
        return True
    
    def get_my_playlists(self, limit, offset):
        user_id = '12185809439'
        playlist_endpoint = f'https://api.spotify.com/v1/users/{user_id}/playlists'
        headers = self.get_bearer_headers()
        data = urlencode({"limit": limit, 'offset':offset})
        # A URL ready string to get user playlists
        lookup_url = f"{playlist_endpoint}?{data}"
        
        res = requests.get(lookup_url, headers=headers)
        
        if res.status_code not in range(200, 299):
            raise Exception(res.json())
        
        self.my_playlists = res.json()['items']
        
    
    def get_playlist(self, playlist_id):
        '''
        Takes a playlistID and return the playlist
        '''
        headers = self.get_bearer_headers()
        playlist_endpoint = f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks"
        
        res = requests.get(playlist_endpoint, headers=headers)
        
        if res.status_code not in range(200, 299):
            raise Exception(res.json())
        return res.json()

# %% [markdown]
# ## Request an Auth Token here
# token expires in an hour, find a way to refresh this token automatically in the future
# https://developer.spotify.com/console/get-playlists/?user_id=12185809439&limit=10&offset=5

# %%
api_key = input('Enter Spotify Auth Token: ')
spotify = SpotifyAPI(api_key)
# Out:
# Enter Spotify Auth Token: BQAAujUbt-QITJO12uoV9qFazkLv_-ywvCoCq1mxSK1xVWtEU8oB8Llz6nP-y5z74QpkTwGrkaGOV-Yx3n1VR_37cvypvIQT4mMRVjH_UdwWEQXu0Xf3IOmZiuDREerNUG8gbTidYm1GTFAMYGl2ZjCBkHTSG1cr2YptJL_ITIYX1ImJ6yrAj3dL

# %%
spotify.get_my_playlists(limit=15, offset=5)
playlists_name = [playlist['name'] for playlist in spotify.my_playlists]
playlists_name
# Out:
# ['My Shazam Tracks',
#  '💣💥',
#  'Sum Good Shit',
#  '浮誇',
#  'Memeingful',
#  'activate your mojo',
#  'goodbye aurabell 9/18-6/19',
#  'OG',
#  '廣東歌',
#  'C',
#  'Generic Trap',
#  'K',
#  'Tokyo Ghoul「東京喰種」',
#  'whitegirl playlist',
#  'Shazam Tracks']

# %% [markdown]
# ## Find tracks in a playlists
# Provide PlaylistID to retrieve contents of this playlist - https://developer.spotify.com/documentation/web-api/reference/playlists/get-playlist/

# %%
top_2019_id = '37i9dQZF1EtsKZinWyvvzX'
top_2018_id = '37i9dQZF1EjefPCsnd'
top_2017_id = '37i9dQZF1E9PDuAPTNqRWN'
top_2016_id = '37i9dQZF1Cz1NXVJwDDfcU'

top_2019 = spotify.get_playlist("37i9dQZF1EtsKZinWyvvzX")
# Extract the items using top_20XX['items'] 

top_2019.keys()
top_2019['items']
# Out:
# [{'added_at': '2019-12-12T21:16:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2kCcBybjl3SAtIcwdWpUe3'},
#       'href': 'https://api.spotify.com/v1/artists/2kCcBybjl3SAtIcwdWpUe3',
#       'id': '2kCcBybjl3SAtIcwdWpUe3',
#       'name': 'Lil Peep',
#       'type': 'artist',
#       'uri': 'spotify:artist:2kCcBybjl3SAtIcwdWpUe3'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3aGFCoR8xGN6DKwvdzeSja'},
#       'href': 'https://api.spotify.com/v1/artists/3aGFCoR8xGN6DKwvdzeSja',
#       'id': '3aGFCoR8xGN6DKwvdzeSja',
#       'name': 'ILOVEMAKONNEN',
#       'type': 'artist',
#       'uri': 'spotify:artist:3aGFCoR8xGN6DKwvdzeSja'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4UXqAaa6dQYAk18Lv7PEgX'},
#       'href': 'https://api.spotify.com/v1/artists/4UXqAaa6dQYAk18Lv7PEgX',
#       'id': '4UXqAaa6dQYAk18Lv7PEgX',
#       'name': 'Fall Out Boy',
#       'type': 'artist',
#       'uri': 'spotify:artist:4UXqAaa6dQYAk18Lv7PEgX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4BQUTZlR3OMrBorJo1ahoY'},
#     'href': 'https://api.spotify.com/v1/albums/4BQUTZlR3OMrBorJo1ahoY',
#     'id': '4BQUTZlR3OMrBorJo1ahoY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739067de29733d1ecf1b87e583',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029067de29733d1ecf1b87e583',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519067de29733d1ecf1b87e583',
#       'width': 64}],
#     'name': "I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)",
#     'release_date': '2019-01-31',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4BQUTZlR3OMrBorJo1ahoY'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2kCcBybjl3SAtIcwdWpUe3'},
#      'href': 'https://api.spotify.com/v1/artists/2kCcBybjl3SAtIcwdWpUe3',
#      'id': '2kCcBybjl3SAtIcwdWpUe3',
#      'name': 'Lil Peep',
#      'type': 'artist',
#      'uri': 'spotify:artist:2kCcBybjl3SAtIcwdWpUe3'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3aGFCoR8xGN6DKwvdzeSja'},
#      'href': 'https://api.spotify.com/v1/artists/3aGFCoR8xGN6DKwvdzeSja',
#      'id': '3aGFCoR8xGN6DKwvdzeSja',
#      'name': 'ILOVEMAKONNEN',
#      'type': 'artist',
#      'uri': 'spotify:artist:3aGFCoR8xGN6DKwvdzeSja'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4UXqAaa6dQYAk18Lv7PEgX'},
#      'href': 'https://api.spotify.com/v1/artists/4UXqAaa6dQYAk18Lv7PEgX',
#      'id': '4UXqAaa6dQYAk18Lv7PEgX',
#      'name': 'Fall Out Boy',
#      'type': 'artist',
#      'uri': 'spotify:artist:4UXqAaa6dQYAk18Lv7PEgX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 233613,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USQX91900290'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2v5JTeM6hSmi5wWy7jiwrI'},
#    'href': 'https://api.spotify.com/v1/tracks/2v5JTeM6hSmi5wWy7jiwrI',
#    'id': '2v5JTeM6hSmi5wWy7jiwrI',
#    'is_local': False,
#    'name': "I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)",
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/113708d3c1425ae8f04571d103c2b87221305c5a?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2v5JTeM6hSmi5wWy7jiwrI'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-12-12T21:16:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/137W8MRPWKqSmrBGDBFSop'},
#       'href': 'https://api.spotify.com/v1/artists/137W8MRPWKqSmrBGDBFSop',
#       'id': '137W8MRPWKqSmrBGDBFSop',
#       'name': 'Wiz Khalifa',
#       'type': 'artist',
#       'uri': 'spotify:artist:137W8MRPWKqSmrBGDBFSop'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1zNqQNIdeOUZHb8zbZRFMX'},
#       'href': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX',
#       'id': '1zNqQNIdeOUZHb8zbZRFMX',
#       'name': 'Swae Lee',
#       'type': 'artist',
#       'uri': 'spotify:artist:1zNqQNIdeOUZHb8zbZRFMX'}],
#     'available_markets': ['AD',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'KZ',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UA',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/70tKSAfnvmCL09IsfeeDxj'},
#     'href': 'https://api.spotify.com/v1/albums/70tKSAfnvmCL09IsfeeDxj',
#     'id': '70tKSAfnvmCL09IsfeeDxj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d7bd17179a6c41ddbddbd4bd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d7bd17179a6c41ddbddbd4bd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d7bd17179a6c41ddbddbd4bd',
#       'width': 64}],
#     'name': 'Hopeless Romantic (feat. Swae Lee)',
#     'release_date': '2018-06-21',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:70tKSAfnvmCL09IsfeeDxj'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/137W8MRPWKqSmrBGDBFSop'},
#      'href': 'https://api.spotify.com/v1/artists/137W8MRPWKqSmrBGDBFSop',
#      'id': '137W8MRPWKqSmrBGDBFSop',
#      'name': 'Wiz Khalifa',
#      'type': 'artist',
#      'uri': 'spotify:artist:137W8MRPWKqSmrBGDBFSop'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1zNqQNIdeOUZHb8zbZRFMX'},
#      'href': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX',
#      'id': '1zNqQNIdeOUZHb8zbZRFMX',
#      'name': 'Swae Lee',
#      'type': 'artist',
#      'uri': 'spotify:artist:1zNqQNIdeOUZHb8zbZRFMX'}],
#    'available_markets': ['AD',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JP',
#     'KW',
#     'KZ',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'RO',
#     'RS',
#     'RU',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'UA',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 225483,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USAT21802517'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4uX8Wh4wxpLne11BhoHs5x'},
#    'href': 'https://api.spotify.com/v1/tracks/4uX8Wh4wxpLne11BhoHs5x',
#    'id': '4uX8Wh4wxpLne11BhoHs5x',
#    'is_local': False,
#    'name': 'Hopeless Romantic (feat. Swae Lee)',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a16785c630c91495e007a0d2917bb0684390d1cc?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4uX8Wh4wxpLne11BhoHs5x'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-12-12T21:16:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15UsOTVnJzReFVN1VCnxy4'},
#       'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#       'id': '15UsOTVnJzReFVN1VCnxy4',
#       'name': 'XXXTENTACION',
#       'type': 'artist',
#       'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2Ti79nwTsont5ZHfdxIzAm'},
#     'href': 'https://api.spotify.com/v1/albums/2Ti79nwTsont5ZHfdxIzAm',
#     'id': '2Ti79nwTsont5ZHfdxIzAm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273806c160566580d6335d1f16c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02806c160566580d6335d1f16c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851806c160566580d6335d1f16c',
#       'width': 64}],
#     'name': '?',
#     'release_date': '2018-03-16',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:2Ti79nwTsont5ZHfdxIzAm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15UsOTVnJzReFVN1VCnxy4'},
#      'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#      'id': '15UsOTVnJzReFVN1VCnxy4',
#      'name': 'XXXTENTACION',
#      'type': 'artist',
#      'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 135090,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG11800209'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0JP9xo3adEtGSdUEISiszL'},
#    'href': 'https://api.spotify.com/v1/tracks/0JP9xo3adEtGSdUEISiszL',
#    'id': '0JP9xo3adEtGSdUEISiszL',
#    'is_local': False,
#    'name': 'Moonlight',
#    'popularity': 86,
#    'preview_url': 'https://p.scdn.co/mp3-preview/91e4395aff0c73f044cf8a7215c08b010bd593e3?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:0JP9xo3adEtGSdUEISiszL'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-12-12T21:16:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5mqguTgtaoCMNMZD6txCh6'},
#       'href': 'https://api.spotify.com/v1/artists/5mqguTgtaoCMNMZD6txCh6',
#       'id': '5mqguTgtaoCMNMZD6txCh6',
#       'name': 'Phum Viphurit',
#       'type': 'artist',
#       'uri': 'spotify:artist:5mqguTgtaoCMNMZD6txCh6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6q6pANmFQbMk7KzlzNeBep'},
#     'href': 'https://api.spotify.com/v1/albums/6q6pANmFQbMk7KzlzNeBep',
#     'id': '6q6pANmFQbMk7KzlzNeBep',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ebefdcb9f6e825e8582bbac4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ebefdcb9f6e825e8582bbac4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ebefdcb9f6e825e8582bbac4',
#       'width': 64}],
#     'name': 'Lover Boy',
#     'release_date': '2018-03-22',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6q6pANmFQbMk7KzlzNeBep'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5mqguTgtaoCMNMZD6txCh6'},
#      'href': 'https://api.spotify.com/v1/artists/5mqguTgtaoCMNMZD6txCh6',
#      'id': '5mqguTgtaoCMNMZD6txCh6',
#      'name': 'Phum Viphurit',
#      'type': 'artist',
#      'uri': 'spotify:artist:5mqguTgtaoCMNMZD6txCh6'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 236727,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR10S1894031'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2rd4FH1cSaWGc0ZiUaMbX9'},
#    'href': 'https://api.spotify.com/v1/tracks/2rd4FH1cSaWGc0ZiUaMbX9',
#    'id': '2rd4FH1cSaWGc0ZiUaMbX9',
#    'is_local': False,
#    'name': 'Lover Boy',
#    'popularity': 67,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a441359cbe1f5d3b0bd1a9643bedeae5c5f454f8?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2rd4FH1cSaWGc0ZiUaMbX9'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-12-12T21:16:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15UsOTVnJzReFVN1VCnxy4'},
#       'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#       'id': '15UsOTVnJzReFVN1VCnxy4',
#       'name': 'XXXTENTACION',
#       'type': 'artist',
#       'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2Ti79nwTsont5ZHfdxIzAm'},
#     'href': 'https://api.spotify.com/v1/albums/2Ti79nwTsont5ZHfdxIzAm',
#     'id': '2Ti79nwTsont5ZHfdxIzAm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273806c160566580d6335d1f16c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02806c160566580d6335d1f16c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851806c160566580d6335d1f16c',
#       'width': 64}],
#     'name': '?',
#     'release_date': '2018-03-16',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:2Ti79nwTsont5ZHfdxIzAm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15UsOTVnJzReFVN1VCnxy4'},
#      'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#      'id': '15UsOTVnJzReFVN1VCnxy4',
#      'name': 'XXXTENTACION',
#      'type': 'artist',
#      'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 166605,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG11800208'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3ee8Jmje8o58CHK66QrVC2'},
#    'href': 'https://api.spotify.com/v1/tracks/3ee8Jmje8o58CHK66QrVC2',
#    'id': '3ee8Jmje8o58CHK66QrVC2',
#    'is_local': False,
#    'name': 'SAD!',
#    'popularity': 87,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5b5a9c4dba2f360fd6cb10df457d2d97ad1ae1f6?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:3ee8Jmje8o58CHK66QrVC2'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-12-12T21:16:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MCBfE4596Uoi2O4DtmEMz'},
#       'href': 'https://api.spotify.com/v1/artists/4MCBfE4596Uoi2O4DtmEMz',
#       'id': '4MCBfE4596Uoi2O4DtmEMz',
#       'name': 'Juice WRLD',
#       'type': 'artist',
#       'uri': 'spotify:artist:4MCBfE4596Uoi2O4DtmEMz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6tkjU4Umpo79wwkgPMV3nZ'},
#     'href': 'https://api.spotify.com/v1/albums/6tkjU4Umpo79wwkgPMV3nZ',
#     'id': '6tkjU4Umpo79wwkgPMV3nZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f7db43292a6a99b21b51d5b4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f7db43292a6a99b21b51d5b4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f7db43292a6a99b21b51d5b4',
#       'width': 64}],
#     'name': 'Goodbye & Good Riddance',
#     'release_date': '2018-12-10',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:6tkjU4Umpo79wwkgPMV3nZ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MCBfE4596Uoi2O4DtmEMz'},
#      'href': 'https://api.spotify.com/v1/artists/4MCBfE4596Uoi2O4DtmEMz',
#      'id': '4MCBfE4596Uoi2O4DtmEMz',
#      'name': 'Juice WRLD',
#      'type': 'artist',
#      'uri': 'spotify:artist:4MCBfE4596Uoi2O4DtmEMz'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 175755,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG11800945'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3oDkdAySo1VQQG0ptV7uwa'},
#    'href': 'https://api.spotify.com/v1/tracks/3oDkdAySo1VQQG0ptV7uwa',
#    'id': '3oDkdAySo1VQQG0ptV7uwa',
#    'is_local': False,
#    'name': 'Lean Wit Me',
#    'popularity': 82,
#    'preview_url': 'https://p.scdn.co/mp3-preview/dd4ae52f5cc30223d1401f6dbbe06e0cfe049116?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:3oDkdAySo1VQQG0ptV7uwa'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-12-12T21:16:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#       'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#       'id': '7n2wHs1TKAczGzO7Dd2rGr',
#       'name': 'Shawn Mendes',
#       'type': 'artist',
#       'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4nDoRrQiYLoBzwC5BhVJzF'},
#       'href': 'https://api.spotify.com/v1/artists/4nDoRrQiYLoBzwC5BhVJzF',
#       'id': '4nDoRrQiYLoBzwC5BhVJzF',
#       'name': 'Camila Cabello',
#       'type': 'artist',
#       'uri': 'spotify:artist:4nDoRrQiYLoBzwC5BhVJzF'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2ZaX1FdZCwchXl1QZiD4O4'},
#     'href': 'https://api.spotify.com/v1/albums/2ZaX1FdZCwchXl1QZiD4O4',
#     'id': '2ZaX1FdZCwchXl1QZiD4O4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6095c382c2853667c1623eb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6095c382c2853667c1623eb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6095c382c2853667c1623eb',
#       'width': 64}],
#     'name': 'Señorita',
#     'release_date': '2019-06-21',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2ZaX1FdZCwchXl1QZiD4O4'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#      'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#      'id': '7n2wHs1TKAczGzO7Dd2rGr',
#      'name': 'Shawn Mendes',
#      'type': 'artist',
#      'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4nDoRrQiYLoBzwC5BhVJzF'},
#      'href': 'https://api.spotify.com/v1/artists/4nDoRrQiYLoBzwC5BhVJzF',
#      'id': '4nDoRrQiYLoBzwC5BhVJzF',
#      'name': 'Camila Cabello',
#      'type': 'artist',
#      'uri': 'spotify:artist:4nDoRrQiYLoBzwC5BhVJzF'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 190960,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71911283'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0TK2YIli7K1leLovkQiNik'},
#    'href': 'https://api.spotify.com/v1/tracks/0TK2YIli7K1leLovkQiNik',
#    'id': '0TK2YIli7K1leLovkQiNik',
#    'is_local': False,
#    'name': 'Señorita',
#    'popularity': 87,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8eab3a5695bfaed5449e0787146f857fb9635907?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0TK2YIli7K1leLovkQiNik'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-12-12T21:16:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1anyVhU62p31KFi8MEzkbf'},
#       'href': 'https://api.spotify.com/v1/artists/1anyVhU62p31KFi8MEzkbf',
#       'id': '1anyVhU62p31KFi8MEzkbf',
#       'name': 'Chance the Rapper',
#       'type': 'artist',
#       'uri': 'spotify:artist:1anyVhU62p31KFi8MEzkbf'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/21WS9wngs9AqFckK7yYJPM'},
#       'href': 'https://api.spotify.com/v1/artists/21WS9wngs9AqFckK7yYJPM',
#       'id': '21WS9wngs9AqFckK7yYJPM',
#       'name': 'PnB Rock',
#       'type': 'artist',
#       'uri': 'spotify:artist:21WS9wngs9AqFckK7yYJPM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5MKInakULmoBNApeB2ZB3A'},
#     'href': 'https://api.spotify.com/v1/albums/5MKInakULmoBNApeB2ZB3A',
#     'id': '5MKInakULmoBNApeB2ZB3A',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f1d4fe9b36aa7be708ea44ea',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f1d4fe9b36aa7be708ea44ea',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f1d4fe9b36aa7be708ea44ea',
#       'width': 64}],
#     'name': 'Cross Me (feat. Chance the Rapper & PnB Rock)',
#     'release_date': '2019-05-24',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5MKInakULmoBNApeB2ZB3A'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#      'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#      'id': '6eUKZXaKkcviH0Ku9w2n3V',
#      'name': 'Ed Sheeran',
#      'type': 'artist',
#      'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1anyVhU62p31KFi8MEzkbf'},
#      'href': 'https://api.spotify.com/v1/artists/1anyVhU62p31KFi8MEzkbf',
#      'id': '1anyVhU62p31KFi8MEzkbf',
#      'name': 'Chance the Rapper',
#      'type': 'artist',
#      'uri': 'spotify:artist:1anyVhU62p31KFi8MEzkbf'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/21WS9wngs9AqFckK7yYJPM'},
#      'href': 'https://api.spotify.com/v1/artists/21WS9wngs9AqFckK7yYJPM',
#      'id': '21WS9wngs9AqFckK7yYJPM',
#      'name': 'PnB Rock',
#      'type': 'artist',
#      'uri': 'spotify:artist:21WS9wngs9AqFckK7yYJPM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 206186,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'GBAHS1900715'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/543bCW2ruMPmxUBWirQ3MR'},
#    'href': 'https://api.spotify.com/v1/tracks/543bCW2ruMPmxUBWirQ3MR',
#    'id': '543bCW2ruMPmxUBWirQ3MR',
#    'is_local': False,
#    'name': 'Cross Me (feat. Chance the Rapper & PnB Rock)',
#    'popularity': 73,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d5caccdfe52737ae696dfc02fdea2c7f5599231d?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:543bCW2ruMPmxUBWirQ3MR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-12-12T21:16:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/35s58BRTGAEWztPo9WqCIs'},
#     'href': 'https://api.spotify.com/v1/albums/35s58BRTGAEWztPo9WqCIs',
#     'id': '35s58BRTGAEWztPo9WqCIs',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e2e352d89826aef6dbd5ff8f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e2e352d89826aef6dbd5ff8f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e2e352d89826aef6dbd5ff8f',
#       'width': 64}],
#     'name': 'Spider-Man: Into the Spider-Verse (Soundtrack From & Inspired by the Motion Picture)',
#     'release_date': '2018-12-14',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:35s58BRTGAEWztPo9WqCIs'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#      'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#      'id': '246dkjvS1zLTtiykXe5h60',
#      'name': 'Post Malone',
#      'type': 'artist',
#      'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1zNqQNIdeOUZHb8zbZRFMX'},
#      'href': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX',
#      'id': '1zNqQNIdeOUZHb8zbZRFMX',
#      'name': 'Swae Lee',
#      'type': 'artist',
#      'uri': 'spotify:artist:1zNqQNIdeOUZHb8zbZRFMX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 158040,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71814888'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3KkXRkHbMCARz0aVfEt68P'},
#    'href': 'https://api.spotify.com/v1/tracks/3KkXRkHbMCARz0aVfEt68P',
#    'id': '3KkXRkHbMCARz0aVfEt68P',
#    'is_local': False,
#    'name': 'Sunflower - Spider-Man: Into the Spider-Verse',
#    'popularity': 87,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f2a0f4db4c1fc8e82ca34295eacf18c95f7de3e5?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:3KkXRkHbMCARz0aVfEt68P'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-12-12T21:16:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15UsOTVnJzReFVN1VCnxy4'},
#       'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#       'id': '15UsOTVnJzReFVN1VCnxy4',
#       'name': 'XXXTENTACION',
#       'type': 'artist',
#       'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1qsQOC4Jn0fnaUZLAbs4dz'},
#     'href': 'https://api.spotify.com/v1/albums/1qsQOC4Jn0fnaUZLAbs4dz',
#     'id': '1qsQOC4Jn0fnaUZLAbs4dz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273da9e59639a9759d8952890c6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02da9e59639a9759d8952890c6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851da9e59639a9759d8952890c6',
#       'width': 64}],
#     'name': 'SKINS',
#     'release_date': '2018-12-07',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:1qsQOC4Jn0fnaUZLAbs4dz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15UsOTVnJzReFVN1VCnxy4'},
#      'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#      'id': '15UsOTVnJzReFVN1VCnxy4',
#      'name': 'XXXTENTACION',
#      'type': 'artist',
#      'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 157776,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUYG1226220'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7pdF27mSDuPWhppnHAmWHa'},
#    'href': 'https://api.spotify.com/v1/tracks/7pdF27mSDuPWhppnHAmWHa',
#    'id': '7pdF27mSDuPWhppnHAmWHa',
#    'is_local': False,
#    'name': 'whoa (mind in awe)',
#    'popularity': 74,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f69b47e8941ef8f49fc89296f9e4099e7a990c8c?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:7pdF27mSDuPWhppnHAmWHa'},
# ...
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 152000,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USAT21812416'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2MShy1GSSgbmGUxADNIao5'},
#    'href': 'https://api.spotify.com/v1/tracks/2MShy1GSSgbmGUxADNIao5',
#    'id': '2MShy1GSSgbmGUxADNIao5',
#    'is_local': False,
#    'name': 'Calling My Spirit',
#    'popularity': 73,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8a9c13460cb94a937e92ee806d498eaed8de2d5e?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:2MShy1GSSgbmGUxADNIao5'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-12-12T21:16:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CajNmpbOovFoOoasH2HaY'},
#       'href': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY',
#       'id': '7CajNmpbOovFoOoasH2HaY',
#       'name': 'Calvin Harris',
#       'type': 'artist',
#       'uri': 'spotify:artist:7CajNmpbOovFoOoasH2HaY'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4A0TivfinfALCAMJqqjZIk'},
#       'href': 'https://api.spotify.com/v1/artists/4A0TivfinfALCAMJqqjZIk',
#       'id': '4A0TivfinfALCAMJqqjZIk',
#       'name': 'Funk Wav',
#       'type': 'artist',
#       'uri': 'spotify:artist:4A0TivfinfALCAMJqqjZIk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2HaqChIDc5go3qxVunBDK0'},
#     'href': 'https://api.spotify.com/v1/albums/2HaqChIDc5go3qxVunBDK0',
#     'id': '2HaqChIDc5go3qxVunBDK0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734d3fa5ce7ba599f4fd7803ef',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024d3fa5ce7ba599f4fd7803ef',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514d3fa5ce7ba599f4fd7803ef',
#       'width': 64}],
#     'name': 'Funk Wav Bounces Vol.1',
#     'release_date': '2017-06-30',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:2HaqChIDc5go3qxVunBDK0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CajNmpbOovFoOoasH2HaY'},
#      'href': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY',
#      'id': '7CajNmpbOovFoOoasH2HaY',
#      'name': 'Calvin Harris',
#      'type': 'artist',
#      'uri': 'spotify:artist:7CajNmpbOovFoOoasH2HaY'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/50co4Is1HCEo8bhOyUWKpn'},
#      'href': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn',
#      'id': '50co4Is1HCEo8bhOyUWKpn',
#      'name': 'Young Thug',
#      'type': 'artist',
#      'uri': 'spotify:artist:50co4Is1HCEo8bhOyUWKpn'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2RdwBSPQiwcmiDo9kixcl8'},
#      'href': 'https://api.spotify.com/v1/artists/2RdwBSPQiwcmiDo9kixcl8',
#      'id': '2RdwBSPQiwcmiDo9kixcl8',
#      'name': 'Pharrell Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:2RdwBSPQiwcmiDo9kixcl8'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#      'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#      'id': '66CXWjxzNUsdJxJ2JdwvnR',
#      'name': 'Ariana Grande',
#      'type': 'artist',
#      'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4A0TivfinfALCAMJqqjZIk'},
#      'href': 'https://api.spotify.com/v1/artists/4A0TivfinfALCAMJqqjZIk',
#      'id': '4A0TivfinfALCAMJqqjZIk',
#      'name': 'Funk Wav',
#      'type': 'artist',
#      'uri': 'spotify:artist:4A0TivfinfALCAMJqqjZIk'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 229160,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'GBARL1700589'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/60APt5N2NRaKWf5xzJdzyC'},
#    'href': 'https://api.spotify.com/v1/tracks/60APt5N2NRaKWf5xzJdzyC',
#    'id': '60APt5N2NRaKWf5xzJdzyC',
#    'is_local': False,
#    'name': 'Heatstroke (feat. Young Thug, Pharrell Williams & Ariana Grande)',
#    'popularity': 59,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a43b6717d8333767b71bbc27e03badbc913c3840?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:60APt5N2NRaKWf5xzJdzyC'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-12-12T21:16:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2a42gzUH51UAvwcfy0N6JT'},
#       'href': 'https://api.spotify.com/v1/artists/2a42gzUH51UAvwcfy0N6JT',
#       'id': '2a42gzUH51UAvwcfy0N6JT',
#       'name': 'Fujitsu',
#       'type': 'artist',
#       'uri': 'spotify:artist:2a42gzUH51UAvwcfy0N6JT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/62MVvI7ZbnVde4NDB6mFhL'},
#     'href': 'https://api.spotify.com/v1/albums/62MVvI7ZbnVde4NDB6mFhL',
#     'id': '62MVvI7ZbnVde4NDB6mFhL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734a22c258883ab16e7250850d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024a22c258883ab16e7250850d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514a22c258883ab16e7250850d',
#       'width': 64}],
#     'name': 'corals 2',
#     'release_date': '2018-09-21',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:62MVvI7ZbnVde4NDB6mFhL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2a42gzUH51UAvwcfy0N6JT'},
#      'href': 'https://api.spotify.com/v1/artists/2a42gzUH51UAvwcfy0N6JT',
#      'id': '2a42gzUH51UAvwcfy0N6JT',
#      'name': 'Fujitsu',
#      'type': 'artist',
#      'uri': 'spotify:artist:2a42gzUH51UAvwcfy0N6JT'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 147692,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEQ021804825'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5rBQIzDduJsmDbZ97gqWEW'},
#    'href': 'https://api.spotify.com/v1/tracks/5rBQIzDduJsmDbZ97gqWEW',
#    'id': '5rBQIzDduJsmDbZ97gqWEW',
#    'is_local': False,
#    'name': 'sand castles',
#    'popularity': 59,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c06822a183031e6e4301e487216a19d489a0d734?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:5rBQIzDduJsmDbZ97gqWEW'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-12-12T21:16:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RDOrhPqAM4jzTRCEb19qX'},
#       'href': 'https://api.spotify.com/v1/artists/2RDOrhPqAM4jzTRCEb19qX',
#       'id': '2RDOrhPqAM4jzTRCEb19qX',
#       'name': 'Sheck Wes',
#       'type': 'artist',
#       'uri': 'spotify:artist:2RDOrhPqAM4jzTRCEb19qX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/15Id9Jrqab8IwHFirdrrLp'},
#     'href': 'https://api.spotify.com/v1/albums/15Id9Jrqab8IwHFirdrrLp',
#     'id': '15Id9Jrqab8IwHFirdrrLp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27359cd47039c5b10ed919fbaa8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0259cd47039c5b10ed919fbaa8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485159cd47039c5b10ed919fbaa8',
#       'width': 64}],
#     'name': 'MUDBOY',
#     'release_date': '2018-10-05',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:15Id9Jrqab8IwHFirdrrLp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RDOrhPqAM4jzTRCEb19qX'},
#      'href': 'https://api.spotify.com/v1/artists/2RDOrhPqAM4jzTRCEb19qX',
#      'id': '2RDOrhPqAM4jzTRCEb19qX',
#      'name': 'Sheck Wes',
#      'type': 'artist',
#      'uri': 'spotify:artist:2RDOrhPqAM4jzTRCEb19qX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 183906,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'QM24S1703585'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1xzBco0xcoJEDXktl7Jxrr'},
#    'href': 'https://api.spotify.com/v1/tracks/1xzBco0xcoJEDXktl7Jxrr',
#    'id': '1xzBco0xcoJEDXktl7Jxrr',
#    'is_local': False,
#    'name': 'Mo Bamba',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0c5fe05f24ebc1237610c99e749e776f93799a2a?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:1xzBco0xcoJEDXktl7Jxrr'},
#   'video_thumbnail': {'url': None}}]

# %%
top_2019['items'][0]['track']['id']
# Out:
# '2v5JTeM6hSmi5wWy7jiwrI'

# %% [markdown]
# ## Class inheritance
# Playlist is a subclass of SpotifyAPI - a few things<br>
# Using the super() method alone returns a temporary object of the superclass that then allows you to call that superclass’s methods.<br>
# If you're using super(), you don't need to specify self explicitly.<br>
# <br>
# Read this for more on Class Inheritance - https://realpython.com/python-super/

# %%
# Make a playlist class that inherit SpotifyAPI class methods
class Playlist(SpotifyAPI):
    tracks = set() # store a set of tracks
    artists = dict() # key:val - artist: {tracks: [{albumTitle, albumURL, imageURL, popularity, released_date},...], number of times artists appeared in playlist,}
    feature = dict() # key:value - artist
    temp_list = []
    
    def __init__(self, playlist_id, *args, **kwargs):
        super().__init__(api_key, client_id=None, client_secret=None, *args, **kwargs)
        self.playlist_id = playlist_id
        self.api_key = api_key
    
    def parse_tracks(self):
        temp_list = []
        playlist_id = self.playlist_id
        playlist_items = self.get_playlist(playlist_id)['items']
        
        if not playlist_items:
            raise Exception('No Playlist, check playlistID')
        
        for item in playlist_items:
            track_dict = parse_track(item)
            temp_list.append(track_dict)
        
        self.tracks = temp_list

# %%
top2019 = Playlist(top_2019_id)
top2019.parse_tracks()
top2019.tracks
# Out:
# [{'lead': {'track': "I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)",
#    'album': "I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)",
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2739067de29733d1ecf1b87e583',
#    'release_date': '2019-01-31',
#    'popularity': 75,
#    'duration': 233}},
#  {'lead': {'track': 'Hopeless Romantic (feat. Swae Lee)',
#    'album': 'Hopeless Romantic (feat. Swae Lee)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273d7bd17179a6c41ddbddbd4bd',
#    'release_date': '2018-06-21',
#    'popularity': 53,
#    'duration': 225}},
#  {'lead': {'track': 'Moonlight',
#    'album': '?',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273806c160566580d6335d1f16c',
#    'release_date': '2018-03-16',
#    'popularity': 86,
#    'duration': 135}},
#  {'lead': {'track': 'Lover Boy',
#    'album': 'Lover Boy',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273ebefdcb9f6e825e8582bbac4',
#    'release_date': '2018-03-22',
#    'popularity': 67,
#    'duration': 236}},
#  {'lead': {'track': 'SAD!',
#    'album': '?',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273806c160566580d6335d1f16c',
#    'release_date': '2018-03-16',
#    'popularity': 87,
#    'duration': 166}},
#  {'lead': {'track': 'Lean Wit Me',
#    'album': 'Goodbye & Good Riddance',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273f7db43292a6a99b21b51d5b4',
#    'release_date': '2018-12-10',
#    'popularity': 82,
#    'duration': 175}},
#  {'lead': {'track': 'Señorita',
#    'album': 'Señorita',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273e6095c382c2853667c1623eb',
#    'release_date': '2019-06-21',
#    'popularity': 87,
#    'duration': 190}},
#  {'lead': {'track': 'Cross Me (feat. Chance the Rapper & PnB Rock)',
#    'album': 'Cross Me (feat. Chance the Rapper & PnB Rock)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273f1d4fe9b36aa7be708ea44ea',
#    'release_date': '2019-05-24',
#    'popularity': 73,
#    'duration': 206}},
#  {'lead': {'track': 'Sunflower - Spider-Man: Into the Spider-Verse',
#    'album': 'Spider-Man: Into the Spider-Verse (Soundtrack From & Inspired by the Motion Picture)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273e2e352d89826aef6dbd5ff8f',
#    'release_date': '2018-12-14',
#    'popularity': 86,
#    'duration': 158}},
#  {'lead': {'track': 'whoa (mind in awe)',
#    'album': 'SKINS',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273da9e59639a9759d8952890c6',
#    'release_date': '2018-12-07',
#    'popularity': 74,
#    'duration': 157}},
#  {'lead': {'track': 'Hide (feat. Seezyn)',
#    'album': 'Spider-Man: Into the Spider-Verse (Soundtrack From & Inspired by the Motion Picture)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273e2e352d89826aef6dbd5ff8f',
#    'release_date': '2018-12-14',
#    'popularity': 77,
#    'duration': 205}},
#  {'lead': {'track': 'Slide (feat. Frank Ocean & Migos)',
#    'album': 'Funk Wav Bounces Vol.1',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2734d3fa5ce7ba599f4fd7803ef',
#    'release_date': '2017-06-30',
#    'popularity': 70,
#    'duration': 230}},
#  {'lead': {'track': 'Noticed',
#    'album': 'Northsbest',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2738314a1eef415b654f433f3aa',
#    'release_date': '2018-10-19',
#    'popularity': 4,
#    'duration': 165}},
#  {'lead': {'track': 'Space Cadet (feat. Gunna)',
#    'album': 'NOT ALL HEROES WEAR CAPES (Deluxe)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2732887f8c05b5a9f1cb105be29',
#    'release_date': '2018-11-06',
#    'popularity': 78,
#    'duration': 203}},
#  {'lead': {'track': 'Used To',
#    'album': 'Goodbye & Good Riddance',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273f7db43292a6a99b21b51d5b4',
#    'release_date': '2018-12-10',
#    'popularity': 74,
#    'duration': 176}},
#  {'lead': {'track': 'Waiting For Love',
#    'album': 'Stories',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2735393c5d3cac806092a9bc468',
#    'release_date': '2015-10-02',
#    'popularity': 79,
#    'duration': 230}},
#  {'lead': {'track': 'Red Rubies',
#    'album': 'Head In The Clouds',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2734aedbebc17bc6ebccad220e9',
#    'release_date': '2018-07-20',
#    'popularity': 45,
#    'duration': 243}},
#  {'lead': {'track': 'My Bad',
#    'album': 'Free Spirit',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273b361ce46dbadbf8a11081b60',
#    'release_date': '2019-04-05',
#    'popularity': 64,
#    'duration': 163}},
#  {'lead': {'track': 'Lucid Dreams',
#    'album': 'Goodbye & Good Riddance',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273f7db43292a6a99b21b51d5b4',
#    'release_date': '2018-12-10',
#    'popularity': 90,
#    'duration': 239}},
#  {'lead': {'track': 'High Right Now',
#    'album': 'Heart Full of Rage',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2736a59c3251231317dfdb9cd9c',
#    'release_date': '2019-02-22',
#    'popularity': 72,
#    'duration': 163}},
#  {'lead': {'track': 'Revenge',
#    'album': '17',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273203c89bd4391468eea4cc3f5',
#    'release_date': '2017-08-25',
#    'popularity': 77,
#    'duration': 120}},
#  {'lead': {'track': 'Close To Me (with Diplo) (feat. Swae Lee)',
#    'album': 'Close To Me (feat. Swae Lee)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273dd640dbca55836e23894212a',
#    'release_date': '2018-10-24',
#    'popularity': 77,
#    'duration': 182}},
#  {'lead': {'track': 'Summertime In Paris',
#    'album': 'ERYS (Deluxe)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b27360ec4df52c2d724bc53ffec5',
#    'release_date': '2019-07-05',
#    'popularity': 77,
#    'duration': 270}},
#  {'lead': {'track': 'Talk To Myself',
#    'album': 'Stories',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2735393c5d3cac806092a9bc468',
#    'release_date': '2015-10-02',
#    'popularity': 53,
#    'duration': 235}},
#  {'lead': {'track': 'Lover Boy 88',
#    'album': 'Head In The Clouds',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2734aedbebc17bc6ebccad220e9',
#    'release_date': '2018-07-20',
#    'popularity': 55,
#    'duration': 233}},
#  {'lead': {'track': 'Middle',
#    'album': 'Encore',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273212d776c31027c511f0ee3bc',
#    'release_date': '2016-08-05',
#    'popularity': 76,
#    'duration': 220}},
#  {'lead': {'track': 'BAD!',
#    'album': 'SKINS',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273da9e59639a9759d8952890c6',
#    'release_date': '2018-12-07',
#    'popularity': 70,
#    'duration': 94}},
#  {'lead': {'track': 'Touch Me',
#    'album': 'Stories',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2735393c5d3cac806092a9bc468',
#    'release_date': '2015-10-02',
#    'popularity': 51,
#    'duration': 186}},
#  {'lead': {'track': 'Peach Jam',
#    'album': 'Head In The Clouds',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2734aedbebc17bc6ebccad220e9',
#    'release_date': '2018-07-20',
#    'popularity': 62,
#    'duration': 161}},
#  {'lead': {'track': 'I THINK',
#    'album': 'IGOR',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2737005885df706891a3c182a57',
#    'release_date': '2019-05-17',
#    'popularity': 73,
#    'duration': 212}},
#  {'lead': {'track': 'Keanu Reeves',
#    'album': 'Keanu Reeves',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273c27ad6f3930a857177ba33dc',
#    'release_date': '2019-01-18',
#    'popularity': 2,
#    'duration': 225}},
#  {'lead': {'track': 'Caught Up (feat. Khalid)',
#    'album': 'Caught Up (feat. Khalid)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2738abe0e9dae9f218368dfb3b5',
#    'release_date': '2019-07-24',
#    'popularity': 69,
#    'duration': 247}},
#  {'lead': {'track': 'Breathe',
#    'album': 'Breathe',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b27321cea5ed05c99d9f132c6cac',
#    'release_date': '2019-09-12',
#    'popularity': 2,
#    'duration': 125}},
#  {'lead': {'track': 'Jocelyn Flores',
#    'album': '17',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273203c89bd4391468eea4cc3f5',
#    'release_date': '2017-08-25',
#    'popularity': 88,
#    'duration': 119}},
#  {'lead': {'track': 'Gemini',
#    'album': 'Heart Full of Rage',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2736a59c3251231317dfdb9cd9c',
#    'release_date': '2019-02-22',
#    'popularity': 56,
#    'duration': 186}},
#  {'lead': {'track': 'Eastside (with Halsey & Khalid)',
#    'album': 'Eastside (with Halsey & Khalid)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2733154f0bdf9a17385d7afc6ba',
#    'release_date': '2018-07-12',
#    'popularity': 81,
#    'duration': 173}},
#  {'lead': {'track': 'Midsummer Madness',
#    'album': 'Head In The Clouds',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2734aedbebc17bc6ebccad220e9',
#    'release_date': '2018-07-20',
#    'popularity': 75,
#    'duration': 280}},
#  {'lead': {'track': 'Find U Again (feat. Camila Cabello)',
#    'album': 'Find U Again (feat. Camila Cabello)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b27318911141cdfc2a1c59169ade',
#    'release_date': '2019-05-30',
#    'popularity': 70,
#    'duration': 176}},
#  {'lead': {'track': 'Addicted To You',
#    'album': 'True',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2734cfcceb6f9b1aae8752810e7',
#    'release_date': '2013-09-13',
#    'popularity': 68,
#    'duration': 148}},
#  {'lead': {'track': 'EARFQUAKE',
#    'album': 'IGOR',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2737005885df706891a3c182a57',
#    'release_date': '2019-05-17',
#    'popularity': 82,
#    'duration': 190}},
#  {'lead': {'track': 'Swimming Pool',
#    'album': 'Head In The Clouds',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2734aedbebc17bc6ebccad220e9',
#    'release_date': '2018-07-20',
#    'popularity': 41,
#    'duration': 272}},
#  {'lead': {'track': 'Better',
#    'album': 'Free Spirit',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273b361ce46dbadbf8a11081b60',
#    'release_date': '2019-04-05',
#    'popularity': 66,
#    'duration': 229}},
#  {'lead': {'track': 'Salute (feat. French Montana)',
#    'album': 'Heart Full of Rage',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2736a59c3251231317dfdb9cd9c',
#    'release_date': '2019-02-22',
#    'popularity': 62,
#    'duration': 182}},
#  {'lead': {'track': 'Everybody Dies In Their Nightmares',
#    'album': '17',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273203c89bd4391468eea4cc3f5',
#    'release_date': '2017-08-25',
#    'popularity': 84,
#    'duration': 95}},
#  {'lead': {'track': 'Katharsis',
#    'album': 'Katharsis',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b27383a0a177ac01d893a9fe1e0f',
#    'release_date': '2018-11-21',
#    'popularity': 63,
#    'duration': 262}},
#  {'lead': {'track': 'MIDDLE CHILD',
#    'album': 'MIDDLE CHILD',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2737f37a4001ae7d8be430bd91b',
#    'release_date': '2019-01-23',
#    'popularity': 83,
#    'duration': 213}},
#  {'lead': {'track': 'Hundred',
#    'album': 'Free Spirit',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273b361ce46dbadbf8a11081b60',
#    'release_date': '2019-04-05',
#    'popularity': 66,
#    'duration': 277}},
#  {'lead': {'track': 'Depression & Obsession',
#    'album': '17',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273203c89bd4391468eea4cc3f5',
#    'release_date': '2017-08-25',
#    'popularity': 74,
#    'duration': 144}},
#  {'lead': {'track': "Ain't What It Seems",
#    'album': 'Heart Full of Rage',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2736a59c3251231317dfdb9cd9c',
#    'release_date': '2019-02-22',
#    'popularity': 49,
#    'duration': 172}},
#  {'lead': {'track': '772 Love',
#    'album': '772 Love',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2737fdf28b1a1cd14c3e84dad2b',
#    'release_date': '2017-10-16',
#    'popularity': 73,
#    'duration': 209}},
#  {'lead': {'track': 'Ten More Days',
#    'album': 'Stories',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2735393c5d3cac806092a9bc468',
#    'release_date': '2015-10-02',
#    'popularity': 54,
#    'duration': 245}},
#  {'lead': {'track': 'the remedy for a broken heart (why am I so in love)',
#    'album': '?',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273806c160566580d6335d1f16c',
#    'release_date': '2018-03-16',
#    'popularity': 83,
#    'duration': 160}},
#  {'lead': {'track': "I'm a Mess",
#    'album': 'Expectations',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b27361fe6d3a50c0beaa3cfe33e9',
#    'release_date': '2018-06-22',
#    'popularity': 79,
#    'duration': 195}},
#  {'lead': {'track': 'Let Me Down Slowly',
#    'album': 'Narrated For You',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273459d675aa0b6f3b211357370',
#    'release_date': '2018-11-16',
#    'popularity': 85,
#    'duration': 169}},
#  {'lead': {'track': 'Unravel',
#    'album': 'Fantastic Magic',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2739b340b4f1068ddf6ade20374',
#    'release_date': '2014-08-27',
#    'popularity': 76,
#    'duration': 238}},
#  {'lead': {'track': 'Sauce!',
#    'album': 'XXXTENTACION Presents: Members Only, Vol. 4',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b27365ba84e2771cc90d8192a06a',
#    'release_date': '2019-01-23',
#    'popularity': 65,
#    'duration': 144}},
#  {'lead': {'track': 'The London (feat. J. Cole & Travis Scott)',
#    'album': 'The London (feat. J. Cole & Travis Scott)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273137c2d3150118e7157800c5b',
#    'release_date': '2019-05-23',
#    'popularity': 78,
#    'duration': 200}},
#  {'lead': {'track': 'Symphony (feat. Zara Larsson)',
#    'album': 'What Is Love? (Deluxe Edition)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b27337fb0680110fbb107740de5d',
#    'release_date': '2018-11-30',
#    'popularity': 75,
#    'duration': 212}},
#  {'lead': {'track': 'Without Me',
#    'album': 'Without Me',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273c42acc1b86597285c2c79559',
#    'release_date': '2018-10-04',
#    'popularity': 84,
#    'duration': 201}},
#  {'lead': {'track': 'Who Shot Johnny?',
#    'album': 'Heart Full of Rage',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2736a59c3251231317dfdb9cd9c',
#    'release_date': '2019-02-22',
#    'popularity': 58,
#    'duration': 165}},
#  {'lead': {'track': 'Robbery',
#    'album': 'Death Race For Love',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273af149eb4002f65f83afc63c4',
#    'release_date': '2019-03-08',
#    'popularity': 88,
#    'duration': 240}},
#  {'lead': {'track': 'Oceans',
#    'album': 'Oceans',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2730f063afecbfa824dce546bd5',
#    'release_date': '2018-12-28',
#    'popularity': 42,
#    'duration': 260}},
#  {'lead': {'track': 'For A Better Day',
#    'album': 'Stories',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2735393c5d3cac806092a9bc468',
#    'release_date': '2015-10-02',
#    'popularity': 67,
#    'duration': 206}},
#  {'lead': {'track': 'Adderall',
#    'album': 'Heart Full of Rage',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2736a59c3251231317dfdb9cd9c',
#    'release_date': '2019-02-22',
#    'popularity': 44,
#    'duration': 168}},
#  {'lead': {'track': 'SLOW DANCING IN THE DARK',
#    'album': 'BALLADS 1',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b27360ba1d6104d0475c7555a6b2',
#    'release_date': '2018-10-26',
#    'popularity': 85,
#    'duration': 209}},
#  {'lead': {'track': "Don't Pretend (feat. SAFE)",
#    'album': 'Free Spirit',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273b361ce46dbadbf8a11081b60',
#    'release_date': '2019-04-05',
#    'popularity': 65,
#    'duration': 165}},
#  {'lead': {'track': 'Dangerous',
#    'album': 'Not 4 Sale',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273cedc24abc2e757d13b386d1e',
#    'release_date': '2008-01-01',
#    'popularity': 68,
#    'duration': 246}},
#  {'lead': {'track': 'Wraith Skating (feat. PnB Rock)',
#    'album': 'Heart Full of Rage',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2736a59c3251231317dfdb9cd9c',
#    'release_date': '2019-02-22',
#    'popularity': 46,
#    'duration': 154}},
#  {'lead': {'track': 'TEST DRIVE',
#    'album': 'BALLADS 1',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b27360ba1d6104d0475c7555a6b2',
#    'release_date': '2018-10-26',
#    'popularity': 73,
#    'duration': 179}},
#  {'lead': {'track': 'Bad At Love',
#    'album': 'hopeless fountain kingdom (Deluxe)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2730f7ad6d8d829906c17cae210',
#    'release_date': '2017-06-02',
#    'popularity': 75,
#    'duration': 181}},
#  {'lead': {'track': 'Swim Good',
#    'album': 'Swim Good',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273ebbff7725d3ce0739be01787',
#    'release_date': '2011-01-01',
#    'popularity': 66,
#    'duration': 257}},
#  {'lead': {'track': 'Solo (feat. Demi Lovato)',
#    'album': 'What Is Love? (Deluxe Edition)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b27337fb0680110fbb107740de5d',
#    'release_date': '2018-11-30',
#    'popularity': 73,
#    'duration': 222}},
#  {'lead': {'track': 'No Stylist (feat. Drake)',
#    'album': 'No Stylist',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273816673ed1db2aa75cfa91843',
#    'release_date': '2018-09-20',
#    'popularity': 72,
#    'duration': 192}},
#  {'lead': {'track': 'NUMB',
#    'album': '?',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273806c160566580d6335d1f16c',
#    'release_date': '2018-03-16',
#    'popularity': 76,
#    'duration': 186}},
#  {'lead': {'track': '100 Degrees',
#    'album': 'The Sailor',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2739f49ffe7fe94bdd0f2f98af2',
#    'release_date': '2019-07-26',
#    'popularity': 70,
#    'duration': 166}},
#  {'lead': {'track': 'I.F.L.Y.',
#    'album': 'Soul Searching',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2733a376bd9b9b1f4b2686807db',
#    'release_date': '2019-08-09',
#    'popularity': 82,
#    'duration': 165}},
#  {'lead': {'track': 'Dangerous (feat. Sam Martin)',
#    'album': 'Listen Again',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273048f37d7b1bba62b93f1009a',
#    'release_date': '2015-11-27',
#    'popularity': 52,
#    'duration': 203}},
#  {'lead': {'track': 'RUNNING OUT OF TIME',
#    'album': 'IGOR',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2737005885df706891a3c182a57',
#    'release_date': '2019-05-17',
#    'popularity': 69,
#    'duration': 177}},
#  {'lead': {'track': 'Self Care',
#    'album': 'Swimming',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273175c577a61aa13d4fb4b6534',
#    'release_date': '2018-08-03',
#    'popularity': 79,
#    'duration': 345}},
#  {'lead': {'track': 'SICKO MODE',
#    'album': 'ASTROWORLD',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273072e9faef2ef7b6db63834a3',
#    'release_date': '2018-08-03',
#    'popularity': 89,
#    'duration': 312}},
#  {'lead': {'track': 'That Girl',
#    'album': '24 HRS (Deluxe)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273b3661a089bc89defa235def3',
#    'release_date': '2016-11-11',
#    'popularity': 56,
#    'duration': 176}},
#  {'lead': {'track': 'Going Bad (feat. Drake)',
#    'album': 'Championships',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273cd63c5962050729d260077d6',
#    'release_date': '2018-11-30',
#    'popularity': 83,
#    'duration': 180}},
#  {'lead': {'track': "They Ain't You",
#    'album': 'Heart Full of Rage',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2736a59c3251231317dfdb9cd9c',
#    'release_date': '2019-02-22',
#    'popularity': 61,
#    'duration': 167}},
#  {'lead': {'track': "CAN'T GET OVER YOU (feat. Clams Casino)",
#    'album': 'BALLADS 1',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b27360ba1d6104d0475c7555a6b2',
#    'release_date': '2018-10-26',
#    'popularity': 75,
#    'duration': 107}},
#  {'lead': {'track': 'Mixed Personalities (feat. Kanye West)',
#    'album': 'We All Shine',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b27318fe5f786c4a429f47b1b253',
#    'release_date': '2019-01-18',
#    'popularity': 76,
#    'duration': 230}},
#  {'lead': {'track': 'Lonely Together - Acoustic',
#    'album': 'Lonely Together (Acoustic)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273464ba9fb0932f5bafba1d3b9',
#    'release_date': '2017-10-27',
#    'popularity': 56,
#    'duration': 182}},
#  {'lead': {'track': 'Chiquita',
#    'album': 'Heart Full of Rage',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2736a59c3251231317dfdb9cd9c',
#    'release_date': '2019-02-22',
#    'popularity': 48,
#    'duration': 155}},
#  {'lead': {'track': 'ATTENTION',
#    'album': 'BALLADS 1',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b27360ba1d6104d0475c7555a6b2',
#    'release_date': '2018-10-26',
#    'popularity': 71,
#    'duration': 128}},
#  {'lead': {'track': 'Rockabye (feat. Sean Paul & Anne-Marie)',
#    'album': 'What Is Love? (Deluxe Edition)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b27337fb0680110fbb107740de5d',
#    'release_date': '2018-11-30',
#    'popularity': 70,
#    'duration': 251}},
#  {'lead': {'track': 'Rollin (feat. Future & Khalid)',
#    'album': 'Funk Wav Bounces Vol.1',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2734d3fa5ce7ba599f4fd7803ef',
#    'release_date': '2017-06-30',
#    'popularity': 64,
#    'duration': 272}},
#  {'lead': {'track': 'Novacane',
#    'album': 'Heart Full of Rage',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2736a59c3251231317dfdb9cd9c',
#    'release_date': '2019-02-22',
#    'popularity': 51,
#    'duration': 211}},
#  {'lead': {'track': 'Swim',
#    'album': 'Narrated For You',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273459d675aa0b6f3b211357370',
#    'release_date': '2018-11-16',
#    'popularity': 61,
#    'duration': 144}},
#  {'lead': {'track': 'Recognize (with Mercer, feat. Majid Jordan) - Mercer Remix',
#    'album': 'Recognize (with Mercer, feat. Majid Jordan) [Mercer Remix]',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2738da21c0da6566b926b7dea6b',
#    'release_date': '2019-09-27',
#    'popularity': 46,
#    'duration': 276}},
#  {'lead': {'track': 'Swervin (feat. 6ix9ine)',
#    'album': 'Hoodie SZN',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273dcfadea246002a5c0fd7b1b8',
#    'release_date': '2018-12-21',
#    'popularity': 82,
#    'duration': 189}},
#  {'lead': {'track': 'The Way I Are',
#    'album': 'Shock Value',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2734ed674ab91bdc566534f9285',
#    'release_date': '2007-01-01',
#    'popularity': 75,
#    'duration': 179}},
#  {'lead': {'track': 'Ocean (feat. Khalid)',
#    'album': 'Ocean (feat. Khalid)',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273b800b91af812df0ce0dd2883',
#    'release_date': '2018-06-15',
#    'popularity': 73,
#    'duration': 216}},
#  {'lead': {'track': 'Calling My Spirit',
#    'album': 'Dying to Live',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b273f9508eb3070b95ceeb82788b',
#    'release_date': '2018-12-14',
#    'popularity': 73,
#    'duration': 152}},
#  {'lead': {'track': 'Heatstroke (feat. Young Thug, Pharrell Williams & Ariana Grande)',
#    'album': 'Funk Wav Bounces Vol.1',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2734d3fa5ce7ba599f4fd7803ef',
#    'release_date': '2017-06-30',
#    'popularity': 59,
#    'duration': 229}},
#  {'lead': {'track': 'sand castles',
#    'album': 'corals 2',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b2734a22c258883ab16e7250850d',
#    'release_date': '2018-09-21',
#    'popularity': 59,
#    'duration': 147}},
#  {'lead': {'track': 'Mo Bamba',
#    'album': 'MUDBOY',
#    'albumImage': 'https://i.scdn.co/image/ab67616d0000b27359cd47039c5b10ed919fbaa8',
#    'release_date': '2018-10-05',
#    'popularity': 79,
#    'duration': 183}}]

# %%
# List of attributes in a single item
print('Item attributes: ', top_2019['items'][0].keys())
print('Track attributes: ', top_2019['items'][0]['track'].keys())


# Interested in album, artists, duration_ms, id, popularity
print('Total Duration (seconds): ', convert_ms(top_2019['items'][0]['track']['duration_ms']))
print('Track Name: ', top_2019['items'][0]['track']['name'])


print('\nAlbum: ', top_2019['items'][0]['track']['album'].keys(), '\n')

# Get first URL of track's album image - Plan to store all images URL in a list and make a map 
print('Album Image: ', top_2019['items'][0]['track']['album']['images'][0]['url'], '\n')

print('Album Name: ', top_2019['items'][13]['track']['album']['name'])
print('Released on: ', top_2019['items'][0]['track']['album']['release_date'])

print('Album popularity: ', top_2019['items'][0]['track']['popularity'])

track_artists = [artist['name'] for artist in top_2019['items'][0]['track']['artists']]
print('Artist: ', track_artists)
# Out:
# Item attributes:  dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# Track attributes:  dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])
# Total Duration (seconds):  233
# Track Name:  I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)
#
# Album:  dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])
#
# Album Image:  https://i.scdn.co/image/ab67616d0000b2739067de29733d1ecf1b87e583
#
# Album Name:  NOT ALL HEROES WEAR CAPES (Deluxe)
# Released on:  2019-01-31
# Album popularity:  75
# Artist:  ['Lil Peep', 'ILOVEMAKONNEN', 'Fall Out Boy']

# %% [markdown]
# ## Retrieve User Playlists
# The data should be included in the url - use library urllib.
# The format of the GET request is as follows - https://developer.spotify.com/console/get-playlists/?user_id=&limit=10&offset=5
